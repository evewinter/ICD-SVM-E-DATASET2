# %% [markdown]
# <a href="https://colab.research.google.com/github/evewinter/ICD-SVM-E-DATASET2/blob/main/Analise_de_Dados_Casas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analise de Dados - Casas

# %%
import pandas as pd


file_path = '1. Casas.csv'
try:
    df = pd.read_csv(file_path)


    if df.shape[1] == 5:

        df.columns = ['distância da praia', 'distância do centro', 'área', 'número de quartos', 'preço']
    else:
        print("Erro: O arquivo CSV deve conter exatamente 5 colunas.")


    print("Dados carregados e colunas renomeadas com sucesso:")
    print(df.head())

except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado.")
except pd.errors.EmptyDataError:
    print("Erro: O arquivo está vazio.")
except pd.errors.ParserError:
    print("Erro: Ocorreu um erro ao ler o arquivo.")
# Out:
# Dados carregados e colunas renomeadas com sucesso:
#    distância da praia  distância do centro   área  número de quartos  \
# 0              272.24               328.24 126.00               3.00
# 1              339.72               260.65 107.00               2.00
# 2              255.94               344.51 134.00               3.00
# 3              435.17               165.10  75.00               1.00
# 4              335.75               264.70 134.00               3.00
#
#        preço
# 0 874,000.00
# 1 893,000.00
# 2 866,000.00
# 3 925,000.00
# 4 866,000.00

# %%
import pandas as pd


file_path = '1. Casas.csv'
try:
    df = pd.read_csv(file_path)


    if df.shape[1] == 5:

        df.columns = ['distância da praia', 'distância do centro', 'área', 'número de quartos', 'preço']


        media = df.mean()
        mediana = df.median()


        desvio_padrao = df.std()
        variancia = df.var()


        minimo = df.min()
        maximo = df.max()


        medidas_df = pd.DataFrame({
            'Média': media,
            'Mediana': mediana,
            'Desvio Padrão': desvio_padrao,
            'Variância': variancia,
            'Mínimo': minimo,
            'Máximo': maximo
        })


        print("Medidas de centralidade, dispersão e extensão dos dados:")
        print(medidas_df)

    else:
        print("Erro: O arquivo CSV deve conter exatamente 5 colunas.")

except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado.")
except pd.errors.EmptyDataError:
    print("Erro: O arquivo está vazio.")
except pd.errors.ParserError:
    print("Erro: Ocorreu um erro ao ler o arquivo.")
# Out:
# Medidas de centralidade, dispersão e extensão dos dados:
#                            Média    Mediana  Desvio Padrão         Variância  \
# distância da praia        227.42     193.16         135.55         18,374.48
# distância do centro       372.96     407.33         135.54         18,370.41
# área                      111.94     110.00          21.38            456.89
# número de quartos           2.16       2.00           0.75              0.56
# preço               1,102,214.75 920,000.00     260,156.39 67,681,346,114.88
#
#                         Mínimo       Máximo
# distância da praia       37.42       519.38
# distância do centro      81.00       562.91
# área                     71.00       149.00
# número de quartos         1.00         3.00
# preço               861,000.00 1,525,530.58

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


file_path = '1. Casas.csv'
try:
    df = pd.read_csv(file_path)

    if df.shape[1] == 5:

        df.columns = ['distância da praia', 'distância do centro', 'área', 'número de quartos', 'preço']


        media = df.mean()
        mediana = df.median()
        desvio_padrao = df.std()
        variancia = df.var()
        minimo = df.min()
        maximo = df.max()


        medidas_df = pd.DataFrame({
            'Média': media,
            'Mediana': mediana,
            'Desvio Padrão': desvio_padrao,
            'Variância': variancia,
            'Mínimo': minimo,
            'Máximo': maximo
        })


        print("Medidas de centralidade, dispersão e extensão dos dados:")
        print(medidas_df)


        for column in df.columns:
            plt.figure(figsize=(10, 4))
            sns.histplot(df[column], bins=10, kde=True)
            plt.title(f'Distribuição de {column}')
            plt.xlabel(column)
            plt.ylabel('Frequência')
            plt.grid(axis='y')
            plt.show()


        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df)
        plt.title('Boxplot Comparativo das Variáveis')
        plt.ylabel('Valores')
        plt.xticks(rotation=45)
        plt.show()

    else:
        print("Erro: O arquivo CSV deve conter exatamente 5 colunas.")

except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado.")
except pd.errors.EmptyDataError:
    print("Erro: O arquivo está vazio.")
except pd.errors.ParserError:
    print("Erro: Ocorreu um erro ao ler o arquivo.")
# Out:
# Medidas de centralidade, dispersão e extensão dos dados:
#                             Média    Mediana  Desvio Padrão     Variância  \
# distância da praia   2.274176e+02     193.16     135.552486  1.837448e+04
# distância do centro  3.729580e+02     407.33     135.537477  1.837041e+04
# área                 1.119388e+02     110.00      21.375032  4.568920e+02
# número de quartos    2.163265e+00       2.00       0.745736  5.561224e-01
# preço                1.102215e+06  920000.00  260156.387803  6.768135e+10
#
#                         Mínimo      Máximo
# distância da praia       37.42      519.38
# distância do centro      81.00      562.91
# área                     71.00      149.00
# número de quartos         1.00        3.00
# preço                861000.00  1525530.58

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")


file_path = '1. Casas.csv'
try:
    df = pd.read_csv(file_path)


    if df.shape[1] == 5:

        df.columns = ['distância da praia', 'distância do centro', 'área', 'número de quartos', 'preço']


        media = df.mean()
        mediana = df.median()
        desvio_padrao = df.std()
        variancia = df.var()
        minimo = df.min()
        maximo = df.max()


        medidas_df = pd.DataFrame({
            'Média': media,
            'Mediana': mediana,
            'Desvio Padrão': desvio_padrao,
            'Variância': variancia,
            'Mínimo': minimo,
            'Máximo': maximo
        })


        print("Medidas de centralidade, dispersão e extensão dos dados:")
        print(medidas_df)


        for column in df.columns:
            plt.figure(figsize=(10, 4))
            sns.histplot(df[column], bins=10, kde=True)
            plt.title(f'Distribuição de {column}')
            plt.xlabel(column)
            plt.ylabel('Frequência')
            plt.show()


        plt.figure(figsize=(10, 6))
        sns.boxplot(data=df)
        plt.title('Boxplot Comparativo das Variáveis')
        plt.ylabel('Valores')
        plt.xticks(rotation=45)
        plt.show()


        correlation_matrix = df.corr()


        plt.figure(figsize=(8, 6))
        sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True, cbar_kws={"shrink": .8})
        plt.title('Matriz de Correlação das Variáveis')
        plt.show()

    else:
        print("Erro: O arquivo CSV deve conter exatamente 5 colunas.")

except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado.")
except pd.errors.EmptyDataError:
    print("Erro: O arquivo está vazio.")
except pd.errors.ParserError:
    print("Erro: Ocorreu um erro ao ler o arquivo.")
# Out:
# Medidas de centralidade, dispersão e extensão dos dados:
#                            Média    Mediana  Desvio Padrão         Variância  \
# distância da praia        227.42     193.16         135.55         18,374.48
# distância do centro       372.96     407.33         135.54         18,370.41
# área                      111.94     110.00          21.38            456.89
# número de quartos           2.16       2.00           0.75              0.56
# preço               1,102,214.75 920,000.00     260,156.39 67,681,346,114.88
#
#                         Mínimo       Máximo
# distância da praia       37.42       519.38
# distância do centro      81.00       562.91
# área                     71.00       149.00
# número de quartos         1.00         3.00
# preço               861,000.00 1,525,530.58
